# %% [markdown]
# # Welcome to the colab project for 47332 AI-orchestrated self-driving labs
# ### Start by cloning all the necessary files from the GitHub repository
#
# ### Once cloned, move into the working directory

# %%
import os

repo_url = "https://github.com/Atuxen/Colorbot2-47332.git"
folder_name = "Colorbot2-47332"

if not os.path.exists(folder_name):
    # !git clone --branch colorbot_wireless {repo_url}
    # %cd {folder_name}/47332-exercises-2025
else:
    # %cd {folder_name}/47332-exercises-2025

# %%
# INSTALL DEPENDENCIES — Run this to install the required packages

# These are required packages for the project
# !pip install pyserial numpy pandas matplotlib botorch scipy torch ipython ipykernel

# %% [markdown]
# # Welcome to Colorbot Exercises
#
# ### Notebooks:
# - [Intro to Colorbot](./exercises/intro.ipynb)
# - [Pump Calibration](./exercises/calibration.ipynb)
# - [Color Mixing](./exercises/mixing.ipynb)

# %% [markdown]
# # 🎨 Welcome to Colorbot 47332
#
# This notebook helps you get started with the Colorbot exercises on Google Colab — no setup needed!
#
# ---
#
# ## 📁 Project Structure
#
# - `pump_controller/` — Python code for controlling the pump system
# - `exercises/` — Jupyter notebooks with experiments and exercises
# - `config_files/` — Configuration files needed by the pump code
# - `logs/` — Log files generated by runs (created automatically)
#
# ---
#
# ## 📘 Notebooks
#
# After setup, you can open and run any of the following:
#
# - [Intro to Colorbot](./exercises/intro.ipynb)
# - [Pump Calibration](./exercises/calibration.ipynb)
# - [Color Mixing](./exercises/mixing.ipynb)
#
# Or browse all notebooks using the left **folder** icon in Colab.
#
# ---
#
# ## ⚠️ Note
#
# - Make sure to run the two setup cells **at the top** of this notebook before continuing.
# - Do **not** install Poetry or try to run `poetry install` — this is handled via pip in Colab.

# %% [markdown]
# 47332-exercises-2025/exercises/start_here.ipynb
